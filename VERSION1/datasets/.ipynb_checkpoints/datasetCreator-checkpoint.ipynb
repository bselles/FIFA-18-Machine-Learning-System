# %%
#IMPORTS NECESARIOS
import numpy as np
import csv
import pandas as pd

from sklearn import preprocessing
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn import svm
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier

# %%
#Cargamos el df asociado al csv situado en path.
def loadDataset(path):
    f = "CompleteDatasets/CompleteDataset.csv"
    names =['Name','Age','Photo','Nationality','Flag','Overall','Potential','Club','Club Logo','Value','Wage','Special','Acceleration','Aggression','Agility','Balance','Ball control','Composure','Crossing','Curve','Dribbling','Finishing','Free kick accuracy','GK diving','GK handling','GK kicking','GK positioning','GK reflexes','Heading accuracy','Interceptions','Jumping','Long passing','Long shots','Marking','Penalties','Positioning','Reactions','Short passing','Shot power','Sliding tackle','Sprint speed','Stamina','Standing tackle','Strength','Vision','Volleys','CAM','CB','CDM','CF','CM','ID','LAM','LB','LCB','LCM','LDM','LF','LM','LS','LW','LWB','Preferred Positions','RAM','RB','RCB','RCM','RDM','RF','RM','RS','RW','RWB','ST'];
    return pd.read_csv(f, names=names).dropna()    #Devolvemos el dataframe.

# %%
#Elimina el resto de las posiciones asociadas a los jugadores del df, dejando 
#solo una posición por jugador.
def pickOnlyOnePosition(df):
    #Para cada jugador, existe un atributo "Preferred Positions".
    #En esta columna del df, pueden aparecer varias posiciones.
    #Cogemos solo la primera posición preferida de cada jugador.
    position= list (df['Preferred Positions'])
    result=list()
    for x in df['Preferred Positions']:
        result.append(x.split(' ')[0])
    df['Preferred Positions']=result
    return df

# %%
#Convierte las atributos no numéricos en numéricos.
def col_to_num(df,feature):
    le = preprocessing.LabelEncoder()
    binary = le.fit_transform(df[feature])
    df[feature] = binary
    return df

# %%
#Elimina atributos innecesarios y cambia a numéricos los atributos no numéricos.
#Algunos atributos, como "Aggression" podrían ser de utilidad pero, pero han sido eliminados para
#evitar tener demasiados.
#Actualmente, tendremos 15 más una columna más que determina la clase (posición)
#del jugador.
def deleteAndChange(df):
    #Transformamos los atributos no numéricos en numéricos.
    #También eliminamos algunos de los atributos no útiles ("Photo", "Name",...) y otros que probablemente serían útiles pero
    #ya había muchos. 
    
    #DISTRIBUCIÓN 1
    #sel_features =['Acceleration','Agility','Ball control','Crossing','Dribbling','Finishing','GK diving','GK reflexes','Interceptions','Long passing','Marking','Short passing','Sprint speed','Strength','Vision','Preferred Positions'];
    
    #DISTRIBUCIÓN 2
    #sel_features =['Acceleration','Aggression','Agility','Balance','Ball control','Composure','Crossing',
    #               'Curve','Dribbling','Finishing',"Free kick accuracy",'GK diving','GK reflexes',
    #               'GK handling', 'GK kicking','GK positioning', 'Heading accuracy','Jumping',
    #               'Interceptions','Long shots','Long passing','Marking','Short passing',
    #               'Positioning','Shot power', 'Sliding tackle', 'Volleys',
    #               'Sprint speed','Strength','Vision','Preferred Positions'];
    
    #DISTRIBUCION 3
    sel_features =['Acceleration','Agility','Ball control','Crossing',
                   'Curve','Dribbling','Finishing','GK diving',
                   'Interceptions','Long shots','Long passing','Marking','Short passing',
                   'Sliding tackle', 'Volleys',
                   'Sprint speed','Strength','Vision','Preferred Positions'];
  
    print(len(sel_features))
    df = df[sel_features]
    non_numeric=['Preferred Positions']
    for f in non_numeric:
        df=col_to_num(df,f)

    return df

# %%
#MAIN
 
df=loadDataset("CompleteDataset.cvs")                 #Cargamos el dataset.
df=pickOnlyOnePosition(df)                            #Eliminamos posiciones redundantes.
df=deleteAndChange(df)                                #Eliminamos atributos inútiles y cambiamos los artributos no numéricos a numéricos.

#Los resultados obtenidos en la transformación de los atributos no numéricos a numéricos puede generar errores
#(valores no válidos). En la parte de octave, se eliminan los valores cuyas clases no se encuentran entre 0 y 13 (un total
# de catorce clases).

display(df)

#Diferenciamos entre ejemplos de entrenamiento, ejemplos de validación y ejemplos de test.
#Los primeros consistirán en el 60% de los ejemplos iniciales. Los segundos y terceros en 20% cada uno.
#x = df.sample(int(len(df)*0.6))     #Cogemos 0.6*len(df) elementos aleatorios del df. Serán los ejemplos de entrenamiento.
#xval= df.sample(int(len(df)*0.2))   #Cogemos 0.2*len(df) elementos aleatorios del df. Serán los datos de validación.
#xtest= df.sample(int(len(df)*0.2))  #Cogemos 0.2*len(df) elementos aleatorios del df. Serán los datos de test.


x= df(2000:8000,:);
xval= x.sample(int(len(x)*0.2));
xtest= x.sample(int(len(x)*0.2));

x.to_csv(path_or_buf="x.csv",header=False,index=False)    #Almacenamos los resultados.
xval.to_csv(path_or_buf="xval.csv",header=False,index=False)    #Almacenamos los resultados.
xtest.to_csv(path_or_buf="xtest.csv",header=False,index=False)    #Almacenamos los resultados.
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 19
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Acceleration Agility Ball control Crossing Curve Dribbling Finishing  \
# 0               89      89           93       85    81        91        94
# 1               92      90           95       77    89        97        95
# 2               94      96           95       75    81        96        89
# 3               88      86           91       77    86        86        94
# 5               79      78           89       62    77        85        91
# 7               93      93           92       80    82        93        83
# 8               60      71           89       85    85        79        76
# 9               78      75           85       68    74        84        91
# 10              75      79           84       66    73        61        60
# 11              76      80           87       90    83        85        83
# 13              88      90           87       80    78        90        85
# 14              75      93           92       78    79        86        71
# 15              93      77           87       87    86        89        87
# 16              90      86           89       70    82        89        90
# 17              68      59           57       58    60        58        33
# 19              88      91           93       80    88        92        85
# 21              87      90           86       82    84        87        88
# 22              77      90           92       72    85        90        69
# 23              95      77           82       77    78        82        88
# 24              62      60           75       44    56        69        39
# 25              72      58           71       69    56        67        34
# 26              62      63           76       55    49        53        42
# 27              62      64           77       64    65        68        55
# 28              75      83           90       82    84        86        74
# 30              70      74           80       60    61        68        38
# 31              63      81           88       76    82        82        87
# 32              87      89           89       80    87        92        85
# 33              82      83           79       67    49        77        65
# 17963        13            45         28           52      48            55
# 17964        11            49         28           50      37            55
# 17965         8            36         33           52      39            52
# 17966        10            44         30           48      44            53
# 17967         7            51         23           25      38            27
# 17968         8            47         17           23      37            26
# 17969        11            11         50           28      12            42
# 17970         6            33         28           35      41            39
# 17971        13            18         51           32      15            46
# 17972        11            41         39           38      49            40
# 17973         7            44         35           44      35            47
# 17974         5            48         16           27      40            30
# 17975        10            31         39           51      37            54
# 17978        11            16         51           30      18            42
# 17979        10            46         32           44      43            49
# 17980        15            38         17           24      38            31
#
#       Sliding tackle Volleys Sprint speed Strength Vision  Preferred Positions
# 0                 23      88           91       80     85                   13
# 1                 26      85           87       59     90                   11
# 2                 33      83           90       53     80                    7
# 3                 38      88           77       80     84                   13
# 5                 19      87           83       84     78                   13
# 7                 22      79           87       65     86                    7
# 8                 69      82           52       74     88                    2
# 9                 18      88           80       85     70                   13
# 10                91      66           77       81     63                    1
# 11                40      82           75       73     90                   10
# 13                35      83           84       72     83                   10
# 14                73      74           71       58     90                    2
# 15                52      76           95       80     79                   11
# 16                12      85           84       74     83                   13
# 17                90      45           78       91     50                    1
# 19                20      88           84       65     84                   13
# 21                11      87           86       61     76                    7
# 22                62      90           68       59     86                    2
# 23                36      86           96       77     77                   13
# 24                88      58           72       85     74                    1
# 25                90      53           78       91     76                    1
# 26                89      47           67       80     52                    1
# 27                90      60           65       85     79                    1
# 28                19      77           68       57     92                   11
# 30                88      63           74       81     74                    1
# 31                27      90           67       88     83                   13
# 32                26      86           86       67     83                   11
# 33                85      56           80       77     76                    4
# 34                79      64           62       56     88                    2
# 35                66      85           76       91     86                    2
# ...              ...     ...          ...      ...    ...                  ...
# 17947             49      25           50       54     30                    5
# 17948             11      35           56       44     41                   13
# 17950             43      35           68       56     46                    6
# 17952             44      32           68       58     42                    4
# 17953             45      38           65       49     45                    9
# 17954             25      37           57       51     42                    6
# 17955             50      28           49       52     47                    4
# 17956             47      20           55       63     32                    1
# 17957             44      28           52       36     38                    9
# 17958             46      21           56       57     32                    1
# 17959             31      41           68       58     47                    0
# 17960             47      42           62       49     53                    0
# 17961             47      20           54       45     27                    1
# 17962             48      26           63       60     32                    1
# 17963             47      30           49       46     47                    4
# 17964             53      31           51       50     51                    4
# 17965             48      37           64       31     40                    4
# 17966             54      31           58       42     51                    4
# 17967             46      23           54       63     32                    9
# 17968             54      21           63       50     32                    1
# 17969             18      36           65       41     47                   13
# 17970             43      19           55       68     31                    1
# 17971             15      35           56       61     48                   13
# 17972             43      33           58       48     40                    1
# 17973             41      33           64       40     40                    4
# 17974             49      24           60       42     28                    1
# 17975             38      34           22       37     43                    4
# 17978             14      33           51       32     37                   13
# 17979             47      25           58       46     51                    4
# 17980             43      19           49       67     22                   13
#
# [15746 rows x 19 columns]
